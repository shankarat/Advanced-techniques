# %%
from IPython.display import IFrame

# %%
# Browse websites which have "https"
IFrame('https://en.wikipedia.org/wiki/HTTPS', width=600, height=250)
# Out:
#         <iframe
#             width="600"
#             height="250"
#             src="https://en.wikipedia.org/wiki/HTTPS"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('https://arxiv.org/pdf/1406.2661.pdf', width=700, height=350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="https://arxiv.org/pdf/1406.2661.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('BX3N0fA5aC0', width=400,height=200)
